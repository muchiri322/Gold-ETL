# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# %%
url ='https://api.collectapi.com/economy/goldPrice'
headers = {
    'content-type': "application/json",
    'authorization': "apikey 2q4fa1KKTXKq71nAkOkccX:20rKC3B3zJuGSDlWvXWooA"
    }
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
data = response.json()
data
# Out:
# {'result': [{'name': 'Gram Altın',
#    'buying': 4285.5,
#    'buyingstr': '4285.50',
#    'selling': 4285.97,
#    'sellingstr': '4285.97',
#    'time': '16:47:45',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:45.000Z',
#    'rate': 0.12},
#   {'name': 'ONS Altın',
#    'buying': 3369.35,
#    'buyingstr': '3369.35',
#    'selling': 3369.75,
#    'sellingstr': '3369.75',
#    'time': '16:47:46',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:46.000Z',
#    'rate': '0'},
#   {'name': 'Çeyrek Altın',
#    'buying': 6941.12,
#    'buyingstr': '6941.12',
#    'selling': 7051.44,
#    'sellingstr': '7051.44',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Yarım Altın',
#    'buying': 13882.25,
#    'buyingstr': '13882.25',
#    'selling': 14124.31,
#    'sellingstr': '14124.31',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Tam Altın',
#    'buying': 27678.8,
#    'buyingstr': '27678.80',
#    'selling': 28120.02,
#    'sellingstr': '28120.02',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Cumhuriyet Altını',
#    'buying': 28321.4975,
#    'buyingstr': '28321.4975',
#    'selling': 28805.871,
#    'sellingstr': '28805.8710',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Gremse Altın',
#    'buying': 68768.5379,
#    'buyingstr': '68768.5379',
#    'selling': 70085.7129,
#    'sellingstr': '70085.7129',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Has Altın',
#    'buying': 4264.07,
#    'buyingstr': '4264.07',
#    'selling': 4264.54,
#    'sellingstr': '4264.54',
#    'time': '16:47:45',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:45.000Z',
#    'rate': 0.12},
#   {'name': 'Çeyrek Altın Eski',
#    'buying': 6812.5841,
#    'buyingstr': '6812.5841',
#    'selling': 6952.8456,
#    'sellingstr': '6952.8456',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Yarım Altın Eski',
#    'buying': 13625.1683,
#    'buyingstr': '13625.1683',
#    'selling': 13845.6791,
#    'sellingstr': '13845.6791',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Tam Altın Eski',
#    'buying': 27250.3365,
#    'buyingstr': '27250.3365',
#    'selling': 27819.9558,
#    'sellingstr': '27819.9558',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': '22 Ayar Bilezik',
#    'buying': 3899.0261,
#    'buyingstr': '3899.0261',
#    'selling': 4029.3927,
#    'sellingstr': '4029.3927',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Gremse Altın Eski',
#    'buying': 68125.8413,
#    'buyingstr': '68125.8413',
#    'selling': 69442.7247,
#    'sellingstr': '69442.7247',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Reşat Lira Altın',
#    'buying': 28492.8833,
#    'buyingstr': '28492.8833',
#    'selling': 28934.4686,
#    'sellingstr': '28934.4686',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Reşat İkibuçuk Altın',
#    'buying': 71253.6314,
#    'buyingstr': '71253.6314',
#    'selling': 72871.9951,
#    'sellingstr': '72871.9951',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Reşat Beşibiryerde',
#    'buying': 142464.4165,
#    'buyingstr': '142464.4165',
#    'selling': 145743.9902,
#    'sellingstr': '145743.9902',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Ata Altın',
#    'buying': 28321.4975,
#    'buyingstr': '28321.4975',
#    'selling': 28805.871,
#    'sellingstr': '28805.8710',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Ziynet Altın',
#    'buying': 27663.85,
#    'buyingstr': '27663.8500',
#    'selling': 28209.76,
#    'sellingstr': '28209.7600',
#    'time': '16:46:19',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:46:19.000Z',
#    'rate': -0.36},
#   {'name': '14 Ayar Altın',
#    'buying': 2473.44,
#    'buyingstr': '2473.4400',
#    'selling': 2475.2,
#    'sellingstr': '2475.2000',
#    'time': '18/06/25',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T15:06:25.000Z',
#    'rate': '0'},
#   {'name': '18 Ayar Altın',
#    'buying': 3155.41,
#    'buyingstr': '3155.4100',
#    'selling': 3158.46,
#    'sellingstr': '3158.4600',
#    'time': '16:46:19',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:46:19.000Z',
#    'rate': -0.36},
#   {'name': 'Beşli Altın',
#    'buying': 137108.6113,
#    'buyingstr': '137108.6113',
#    'selling': 145743.9902,
#    'sellingstr': '145743.9902',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'Hamit Altın',
#    'buying': 28278.6511,
#    'buyingstr': '28278.6511',
#    'selling': 29148.798,
#    'sellingstr': '29148.7980',
#    'time': '16:47:44',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:44.000Z',
#    'rate': 0.1},
#   {'name': 'İkibuçuk Altın',
#    'buying': 69429.92,
#    'buyingstr': '69429.9200',
#    'selling': 70521.47,
#    'sellingstr': '70521.4700',
#    'time': '18/06/25',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T15:06:25.000Z',
#    'rate': '0'},
#   {'name': 'Altın Gümüş',
#    'buying': 92.75,
#    'buyingstr': '92.7500',
#    'selling': 92.75,
#    'sellingstr': '92.7500',
#    'time': '16:47:45',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:45.000Z',
#    'rate': 1.07},
#   {'name': 'ONS EUR',
#    'buying': 2935.45,
#    'buyingstr': '2935.4500',
#    'selling': 2936.12,
#    'sellingstr': '2936.1200',
#    'time': '16:47:41',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:41.000Z',
#    'rate': 0.04},
#   {'name': 'Gümüş',
#    'buying': 46.1831,
#    'buyingstr': '46.1831',
#    'selling': 46.2339,
#    'sellingstr': '46.2339',
#    'time': '16:47:25',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T13:47:25.000Z',
#    'rate': -0.91}],
#  'success': True}

# %%
gold_price = []
gold_price.append(data)

# %%
gold_price
# Out:
# [{'result': [{'name': 'Gram Altın',
#     'buying': 4285.5,
#     'buyingstr': '4285.50',
#     'selling': 4285.97,
#     'sellingstr': '4285.97',
#     'time': '16:47:45',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:45.000Z',
#     'rate': 0.12},
#    {'name': 'ONS Altın',
#     'buying': 3369.35,
#     'buyingstr': '3369.35',
#     'selling': 3369.75,
#     'sellingstr': '3369.75',
#     'time': '16:47:46',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:46.000Z',
#     'rate': '0'},
#    {'name': 'Çeyrek Altın',
#     'buying': 6941.12,
#     'buyingstr': '6941.12',
#     'selling': 7051.44,
#     'sellingstr': '7051.44',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Yarım Altın',
#     'buying': 13882.25,
#     'buyingstr': '13882.25',
#     'selling': 14124.31,
#     'sellingstr': '14124.31',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Tam Altın',
#     'buying': 27678.8,
#     'buyingstr': '27678.80',
#     'selling': 28120.02,
#     'sellingstr': '28120.02',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Cumhuriyet Altını',
#     'buying': 28321.4975,
#     'buyingstr': '28321.4975',
#     'selling': 28805.871,
#     'sellingstr': '28805.8710',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Gremse Altın',
#     'buying': 68768.5379,
#     'buyingstr': '68768.5379',
#     'selling': 70085.7129,
#     'sellingstr': '70085.7129',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Has Altın',
#     'buying': 4264.07,
#     'buyingstr': '4264.07',
#     'selling': 4264.54,
#     'sellingstr': '4264.54',
#     'time': '16:47:45',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:45.000Z',
#     'rate': 0.12},
#    {'name': 'Çeyrek Altın Eski',
#     'buying': 6812.5841,
#     'buyingstr': '6812.5841',
#     'selling': 6952.8456,
#     'sellingstr': '6952.8456',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Yarım Altın Eski',
#     'buying': 13625.1683,
#     'buyingstr': '13625.1683',
#     'selling': 13845.6791,
#     'sellingstr': '13845.6791',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Tam Altın Eski',
#     'buying': 27250.3365,
#     'buyingstr': '27250.3365',
#     'selling': 27819.9558,
#     'sellingstr': '27819.9558',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': '22 Ayar Bilezik',
#     'buying': 3899.0261,
#     'buyingstr': '3899.0261',
#     'selling': 4029.3927,
#     'sellingstr': '4029.3927',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Gremse Altın Eski',
#     'buying': 68125.8413,
#     'buyingstr': '68125.8413',
#     'selling': 69442.7247,
#     'sellingstr': '69442.7247',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Reşat Lira Altın',
#     'buying': 28492.8833,
#     'buyingstr': '28492.8833',
#     'selling': 28934.4686,
#     'sellingstr': '28934.4686',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Reşat İkibuçuk Altın',
#     'buying': 71253.6314,
#     'buyingstr': '71253.6314',
#     'selling': 72871.9951,
#     'sellingstr': '72871.9951',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Reşat Beşibiryerde',
#     'buying': 142464.4165,
#     'buyingstr': '142464.4165',
#     'selling': 145743.9902,
#     'sellingstr': '145743.9902',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Ata Altın',
#     'buying': 28321.4975,
#     'buyingstr': '28321.4975',
#     'selling': 28805.871,
#     'sellingstr': '28805.8710',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Ziynet Altın',
#     'buying': 27663.85,
#     'buyingstr': '27663.8500',
#     'selling': 28209.76,
#     'sellingstr': '28209.7600',
#     'time': '16:46:19',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:46:19.000Z',
#     'rate': -0.36},
#    {'name': '14 Ayar Altın',
#     'buying': 2473.44,
#     'buyingstr': '2473.4400',
#     'selling': 2475.2,
#     'sellingstr': '2475.2000',
#     'time': '18/06/25',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T15:06:25.000Z',
#     'rate': '0'},
#    {'name': '18 Ayar Altın',
#     'buying': 3155.41,
#     'buyingstr': '3155.4100',
#     'selling': 3158.46,
#     'sellingstr': '3158.4600',
#     'time': '16:46:19',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:46:19.000Z',
#     'rate': -0.36},
#    {'name': 'Beşli Altın',
#     'buying': 137108.6113,
#     'buyingstr': '137108.6113',
#     'selling': 145743.9902,
#     'sellingstr': '145743.9902',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'Hamit Altın',
#     'buying': 28278.6511,
#     'buyingstr': '28278.6511',
#     'selling': 29148.798,
#     'sellingstr': '29148.7980',
#     'time': '16:47:44',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:44.000Z',
#     'rate': 0.1},
#    {'name': 'İkibuçuk Altın',
#     'buying': 69429.92,
#     'buyingstr': '69429.9200',
#     'selling': 70521.47,
#     'sellingstr': '70521.4700',
#     'time': '18/06/25',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T15:06:25.000Z',
#     'rate': '0'},
#    {'name': 'Altın Gümüş',
#     'buying': 92.75,
#     'buyingstr': '92.7500',
#     'selling': 92.75,
#     'sellingstr': '92.7500',
#     'time': '16:47:45',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:45.000Z',
#     'rate': 1.07},
#    {'name': 'ONS EUR',
#     'buying': 2935.45,
#     'buyingstr': '2935.4500',
#     'selling': 2936.12,
#     'sellingstr': '2936.1200',
#     'time': '16:47:41',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:41.000Z',
#     'rate': 0.04},
#    {'name': 'Gümüş',
#     'buying': 46.1831,
#     'buyingstr': '46.1831',
#     'selling': 46.2339,
#     'sellingstr': '46.2339',
#     'time': '16:47:25',
#     'date': '2025-06-19',
#     'datetime': '2025-06-19T13:47:25.000Z',
#     'rate': -0.91}],
#   'success': True}]

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                result  success
# 0   {'name': 'Gram Altın', 'buying': 4285.5, 'buyi...     True
# 1   {'name': 'ONS Altın', 'buying': 3369.35, 'buyi...     True
# 2   {'name': 'Çeyrek Altın', 'buying': 6941.12, 'b...     True
# 3   {'name': 'Yarım Altın', 'buying': 13882.25, 'b...     True
# 4   {'name': 'Tam Altın', 'buying': 27678.8, 'buyi...     True
# 5   {'name': 'Cumhuriyet Altını', 'buying': 28321....     True
# 6   {'name': 'Gremse Altın', 'buying': 68768.5379,...     True
# 7   {'name': 'Has Altın', 'buying': 4264.07, 'buyi...     True
# 8   {'name': 'Çeyrek Altın Eski', 'buying': 6812.5...     True
# 9   {'name': 'Yarım Altın Eski', 'buying': 13625.1...     True
# 10  {'name': 'Tam Altın Eski', 'buying': 27250.336...     True
# 11  {'name': '22 Ayar Bilezik', 'buying': 3899.026...     True
# 12  {'name': 'Gremse Altın Eski', 'buying': 68125....     True
# 13  {'name': 'Reşat Lira Altın', 'buying': 28492.8...     True
# 14  {'name': 'Reşat İkibuçuk Altın', 'buying': 712...     True
# 15  {'name': 'Reşat Beşibiryerde', 'buying': 14246...     True
# 16  {'name': 'Ata Altın', 'buying': 28321.4975, 'b...     True
# 17  {'name': 'Ziynet Altın', 'buying': 27663.85, '...     True
# 18  {'name': '14 Ayar Altın', 'buying': 2473.44, '...     True
# 19  {'name': '18 Ayar Altın', 'buying': 3155.41, '...     True
# 20  {'name': 'Beşli Altın', 'buying': 137108.6113,...     True
# 21  {'name': 'Hamit Altın', 'buying': 28278.6511, ...     True
# 22  {'name': 'İkibuçuk Altın', 'buying': 69429.92,...     True
# 23  {'name': 'Altın Gümüş', 'buying': 92.75, 'buyi...     True
# 24  {'name': 'ONS EUR', 'buying': 2935.45, 'buying...     True
# 25  {'name': 'Gümüş', 'buying': 46.1831, 'buyingst...     True
