# %%
import requests
import pandas as pd
from sqlalchemy import create_engine

# %%
url ='https://api.collectapi.com/economy/goldPrice'
headers = {
    'content-type': "application/json",
    'authorization': "apikey 2q4fa1KKTXKq71nAkOkccX:20rKC3B3zJuGSDlWvXWooA"
    }
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
data = response.json()
gold=data['result']

# %%
gold_price = []
gold_price.append(gold)

# %%
gold_price
# Out:
# [[{'name': 'Gram Altın',
#    'buying': 4281.02,
#    'buyingstr': '4281.02',
#    'selling': 4281.49,
#    'sellingstr': '4281.49',
#    'time': '17:57:11',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T14:57:11.000Z',
#    'rate': 0.01},
#   {'name': 'ONS Altın',
#    'buying': 3364.97,
#    'buyingstr': '3364.97',
#    'selling': 3365.4,
#    'sellingstr': '3365.40',
#    'time': '17:57:14',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T14:57:14.000Z',
#    'rate': -0.13},
#   {'name': 'Çeyrek Altın',
#    'buying': 6934.42,
#    'buyingstr': '6934.42',
#    'selling': 7044.12,
#    'sellingstr': '7044.12',
#    'time': '17:57:12',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T14:57:12.000Z',
#    'rate': '0'},
#   {'name': 'Yarım Altın',
#    'buying': 13868.83,
#    'buyingstr': '13868.83',
#    'selling': 14109.66,
#    'sellingstr': '14109.66',
#    'time': '17:57:12',
#    'date': '2025-06-19',
#    'datetime': '2025-06-19T14:57:12.000Z',
# ...

# %%
df=pd.DataFrame(gold)

# %%
df
# Out:
#                     name       buying    buyingstr      selling   sellingstr  \
# 0             Gram Altın    4281.0200      4281.02    4281.4900      4281.49
# 1              ONS Altın    3364.9700      3364.97    3365.4000      3365.40
# 2           Çeyrek Altın    6934.4200      6934.42    7044.1200      7044.12
# 3            Yarım Altın   13868.8300     13868.83   14109.6600     14109.66
# 4              Tam Altın   27652.0500     27652.05   28090.8600     28090.86
# 5      Cumhuriyet Altını   28294.1278   28294.1278   28775.9988   28775.9988
# 6           Gremse Altın   68702.0804   68702.0804   70013.0328   70013.0328
# 7              Has Altın    4259.6100      4259.61    4260.0800      4260.08
# 8      Çeyrek Altın Eski    6806.0005    6806.0005    6945.6354    6945.6354
# 9       Yarım Altın Eski   13612.0010   13612.0010   13831.3208   13831.3208
# 10        Tam Altın Eski   27224.0019   27224.0019   27791.1060   27791.1060
# ...

# %%
engine = create_engine("postgresql://avnadmin:AVNS_VLWGqlg5qAufakXzxN-@pg-30c053dc-muchiridennis036-ea00.f.aivencloud.com:24608/defaultdb")

# %%
df.to_sql('gold_prices', engine, if_exists='replace', index=False, schema='gold')
# Out:
# 26
